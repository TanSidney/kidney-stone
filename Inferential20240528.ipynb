# %% [markdown]
# # About the dataset
#
# Kidney_Stone_Data
#
# source
#
# https://www.kaggle.com/datasets/utkarshxy/kidney-stone-data/data
#
# Introduction
# In 1986, a group of urologists in London published a research paper in The British Medical Journal that compared the effectiveness of two different methods to remove kidney stones. Treatment A was open surgery (invasive), and treatment B was percutaneous nephrolithotomy (less invasive).
#
# When they looked at the results from 700 patients, treatment B had a higher success rate. However, when they only looked at the subgroup of patients different kidney stone sizes, treatment A had a better success rate.
#
# Simpon's paradox occurs when trends appear in subgroups but disappear or reverse when subgroups are combined.
# In this project -> medical data published in 1986 in "The British Medical Journal" where the effectiveness of two types of kidney stone removal treatments (A - open surgery and B - percutaneous nephrolithotomy) were compared.
#
# Using multiple logistic regression and visualize model output to help the doctors determine if there is a difference between the two treatments. While not required, it will also help to have some knowledge of inferential statistics.
#
# Content
# The data contains three columns: treatment (A or B), stone_size (large or small) and success (0 = Failure or 1 = Success).

# %%
#Install the library

# !pip install scipy
# Out:
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy) (1.25.2)

# %%
#Import all the impoortant Library

import pandas as pd
from scipy.stats import ttest_ind, f_oneway, chi2_contingency

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
#Load the data
data = pd.read_csv("Kidney_stone_data.csv")
df = pd.DataFrame(data)

# %%
import matplotlib.pyplot as plt

# %%
data.head(2)
# Out:
#   treatment stone_size  success
# 0         B      large        1
# 1         A      large        1

# %%
df.tail(3)
# Out:
#     treatment stone_size  success
# 697         B      small        1
# 698         A      large        1
# 699         A      small        1

# %%
df.dtypes
# Out:
# treatment     object
# stone_size    object
# success        int64
# dtype: object

# %%
df.describe()
# Out:
#           success
# count  700.000000
# mean     0.802857
# std      0.398126
# min      0.000000
# 25%      1.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000

# %% [markdown]
# ## T-TEST
#
# H0: There is no significant difference between the success rate of Treatment A and Treatment B.*italicized text*
#
# H1: There is a significance difference between the sucess rate of Treatment A and Treatment B.
#
# If your p-value is less than or equal to 0.05 (the significance level), you would conclude that your result is statistically significant. This means the evidence is strong enough to reject the null hypothesis in favor of the alternative hypothesis

# %%
#Sucess rate of Treatment A and Treatment B
success_A = df[df['treatment'] == 'A']['success']
success_B = df[df['treatment'] == 'B']['success']

#Perform Independent Sample T-test
t_stat = ttest_ind(success_A, success_B)
print(t_stat)
# Out:
# TtestResult(statistic=-1.5204003013436962, pvalue=0.12886323855136153, df=698.0)

# %% [markdown]
# #ANOVA

# %%
#Sucess rate of Treatment A and Treatment B
success_small = df[df['stone_size'] == 'small']['success']
success_large = df[df['stone_size'] == 'large']['success']

anova = f_oneway(success_small, success_large)
print(anova)
# Out:
# F_onewayResult(statistic=30.264409926452775, pvalue=5.2953760011433365e-08)

# %% [markdown]
# ## Chi Square

# %%
chi = pd.crosstab([df['treatment'], df['stone_size']], df['success'])
result = chi2_contingency(chi)
print(result)
# Out:
# Chi2ContingencyResult(statistic=31.51349743413072, pvalue=6.626702248891721e-07, dof=3, expected_freq=array([[ 51.84857143, 211.15142857],
#        [ 17.15142857,  69.84857143],
#        [ 15.77142857,  64.22857143],
#        [ 53.22857143, 216.77142857]]))

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data from CSV file
data = pd.read_csv('Kidney_stone_data.csv')

# Extract values from DataFrame
values = data['treatment']

# Plot histogram
plt.hist(values, bins=10, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Kidney Stone Data')

# Show plot
plt.show()

# %%
# Load data from CSV file
data = pd.read_csv('Kidney_stone_data.csv')

# Extract values from DataFrame
values = data['stone_size']

# Plot histogram
plt.hist(values, bins=10, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Kidney Stone Data')

# Show plot
plt.show()

# %%
# Load data from CSV file
data = pd.read_csv('Kidney_stone_data.csv')

# Extract values from DataFrame
values = data['success']

# Plot histogram
plt.hist(values, bins=10, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Kidney Stone Data')

# Show plot
plt.show()

# %% [markdown]
# **T-test Results:**
#
# Statistic: -1.52
# p-value: 0.129
# Conclusion: There is no statistically significant difference between treatment A and B (p > 0.05).
#
# **ANOVA Results:**
#
# Statistic: 30.26
# p-value: 5.30e-08
# Conclusion: There are significant differences on the success rate of treatment between large and small stone sizes (p < 0.05).
#
# **Chi-Squared Results:**
#
# Statistic: 31.51
# p-value: 6.63e-07
# Conclusion: There is a significant association between the treatment, stone size and success variables (p < 0.05).
#
# **Summary Conclusion:**
#
# t-test suggests no significant difference between two specific groups, the ANOVA indicates significant differences among multiple groups, and the chi-squared test reveals a significant association between certain categorical variables. This implies that different treatment methods likely have varying effectiveness and that there is a meaningful relationship between different treatment types and their outcomes.
